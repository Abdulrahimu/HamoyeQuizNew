# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('energydata_complete.csv')
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
df.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
plt.figure(figsize=(15,9))
sns.regplot(x='T2',y='T6',data=df)
# Out:
# <AxesSubplot:xlabel='T2', ylabel='T6'>

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df.T2, df.T6, test_size=0.3, random_state=42)
linear_model = LinearRegression()
linear_model.fit(x_train.values.reshape(-1,1),y_train)
predicted_values = linear_model.predict(x_test.values.reshape(-1,1))

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
print('R2_Score is: ', r2_score)
# Out:
# R2_Score is:  0.6427789637197382

# %%
scaler = MinMaxScaler()
df_new = df.drop(columns=['date','lights'])
normalised_df = pd.DataFrame(scaler.fit_transform(df_new),columns=df_new.columns)
features_df = normalised_df.drop(columns=['Appliances'])
target = normalised_df['Appliances']

# %%
x_train, x_test, y_train, y_test = train_test_split(features_df, target, train_size=0.3, random_state=42)
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
predicted_values = linear_model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values)
print('The Mean Absolute Error is: ', mae)
# Out:
# The Mean Absolute Error is:  0.05004159363826472

# %%
residual_sum = np.sum(np.square(y_test - predicted_values))
print('The Residual Sum of Sum of Squares is: ',round(residual_sum,2))
# Out:
# The Residual Sum of Sum of Squares is:  111.0

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
print('The Coefficient of Determination (R2_Score) is: ', r2_score)
# Out:
# The Coefficient of Determination (R2_Score) is:  0.14347958498194013

# %%
def get_weights_df(model, feat, col_name):
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight')
linear_model_weights.sort_values(by='Linear_Model_Weight', ascending=False)
# Out:
#        Features  Linear_Model_Weight
# 25         RH_1             0.558100
# 24           T3             0.292463
# 23           T6             0.236490
# 22           T8             0.113388
# 21         RH_3             0.098584
# 20    Tdewpoint             0.068642
# 19         RH_6             0.044838
# 18    Windspeed             0.035072
# 17           T4             0.029408
# 16         RH_5             0.023723
# 15   Visibility             0.016239
# 14  Press_mm_hg             0.013672
# 13           T1             0.004817
# 12          rv1            -0.000730
# 11          rv2            -0.000730
# 10           T7            -0.008981
# 9          RH_4            -0.020727
# 8          RH_7            -0.023157
# 7            T5            -0.023826
# 6          RH_9            -0.028465
# 5        RH_out            -0.043873
# 4          RH_8            -0.173404
# 3            T9            -0.181327
# 2            T2            -0.241125
# ...

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=0.4)
ridge.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
from sklearn.metrics import mean_squared_error
ridge_pred = ridge.predict(x_test)

# Calculating the root mean squared error
rmse = np.sqrt(mean_squared_error(y_test, ridge_pred))
print('The root mean squared error (rmse) is: ', round(rmse, 3))
# Out:
# The root mean squared error (rmse) is:  0.09

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.001)
lasso.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
lasso_weights_df = get_weights_df(lasso, x_train, 'Lasso_weight')
lasso_weights_df
# Out:
#        Features  Lasso_weight
# 0        RH_out     -0.041568
# 1          RH_8     -0.001878
# 2            T1      0.000000
# 3     Tdewpoint      0.000000
# 4    Visibility      0.000000
# 5   Press_mm_hg     -0.000000
# 6         T_out      0.000000
# 7          RH_9     -0.000000
# 8            T9     -0.000000
# 9            T8      0.000000
# 10         RH_7     -0.000000
# 11          rv1     -0.000000
# 12           T7     -0.000000
# 13           T6      0.000000
# 14         RH_5      0.000000
# 15           T5     -0.000000
# 16         RH_4      0.000000
# 17           T4      0.000000
# 18         RH_3      0.000000
# 19           T3      0.000000
# 20         RH_2     -0.000000
# 21           T2      0.000000
# 22         RH_6     -0.000000
# 23          rv2     -0.000000
# 24    Windspeed      0.005877
# 25         RH_1      0.007372

# %%
# The new RMSE after applying the Lasso Regression
lasso_pred = lasso.predict(x_test)

rmse = np.sqrt(mean_squared_error(y_test, lasso_pred))
print('The root mean squared error (rmse) is: ', round(rmse, 3))
# Out:
# The root mean squared error (rmse) is:  0.096
